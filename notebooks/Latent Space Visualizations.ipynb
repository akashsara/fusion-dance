# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import torch
import numpy as np
import pandas as pd
import plotly.express as px

# %%
# Config
# embedding_location = "../outputs/vq_vae_v5.8/embeddings.pt"
embedding_location = "../outputs/vq_vae_v5.8/encodings.pt"
# embedding_location = "../outputs/convolutional_vae_v16.5/embeddings.pt"
# embedding_location = "../outputs/tinyhero_vq_vae_v2.1/embeddings.pt"
# embedding_location = "../outputs/tinyhero_vq_vae_v2.1/encodings.pt"
pokemon = True

# %%
checkpoint = torch.load(embedding_location)
embeddings = checkpoint['embeddings']
filenames = checkpoint['filenames']
meta_information = checkpoint['color']

# %%
# Config
num_embeddings = embeddings.shape[0]
embeddings = embeddings.reshape(num_embeddings, -1)
# embeddings = embeddings * 512 # Use with encodings; swap the number for num_classes
label = "bmi" # For Pokemon: height, weight, type1, type2, egg1, egg2, bmi; else "pose"

# %%
if pokemon:
    all_colors = pd.DataFrame(meta_information, columns=["height", "weight", "type1", "type2", "egg1", "egg2"])
    if label in ["height", "weight"]:
        colors = pd.qcut(all_colors[label], 10)
    elif label == "bmi":
        colors = pd.qcut(all_colors["weight"] / all_colors["height"], 10)
    else:
        colors = all_colors[label]
else:
    colors = meta_information

# %%
colors.shape
# Out:
# (740,)

# %%
embeddings.shape
# Out:
# torch.Size([740, 1024])

# %%
embeddings[0]
# Out:
# tensor([0.5938, 0.5938, 0.5938,  ..., 0.5938, 0.5938, 0.5938])

# %% [markdown]
# # 2D t-SNE

# %%
tsne = TSNE(n_components=2, init='pca', perplexity=50, learning_rate='auto', verbose=1).fit_transform(embeddings)
# Out:
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 740 samples in 0.003s...
# [t-SNE] Computed neighbors for 740 samples in 0.133s...
# [t-SNE] Computed conditional probabilities for sample 740 / 740
# [t-SNE] Mean sigma: 1.092128
# e:\dev\fusion-dance\env\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 89.222946
# [t-SNE] KL divergence after 1000 iterations: 1.769850

# %%
fig = px.scatter(tsne, x=0, y=1, color=colors, labels={'color': label}, hover_name=filenames, title='2D t-SNE')
fig.show()
# Out:
# <div>                            <div id="2b9e62c1-7a3f-47aa-a88e-7926ca54785d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2b9e62c1-7a3f-47aa-a88e-7926ca54785d")) {                    Plotly.newPlot(                        "2b9e62c1-7a3f-47aa-a88e-7926ca54785d",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>bmi=(8.325, 12.267]<br>0=%{x}<br>1=%{y}<extra></extra>","hovertext":["Bulbasaur","Caterpie","Weedle","Rattata","Jigglypuff","Wigglytuff","Zubat","Oddish","Gloom","Venomoth","Meowth","Victreebel","Magikarp","Mew","Ledyba","Cleffa","Natu","Xatu","Sunflora","Unown-a","Unown-b","Unown-c","Unown-d","Unown-exclamation","Unown-e","Unown-f","Unown-g","Unown-h","Unown-i","Unown-j","Unown-k","Unown-l","Unown-m","Unown-n","Unown-o","Unown-p","Unown-question","Unown-q","Unown-r","Unown-s","Unown-t","Unown-u","Unown-v","Unown-w","Unown-x","Unown-y","Unown-z","Unown","Pineco","Dunsparce","Corsola","Celebi","Treecko","Wurmple","Shroomish","Nincada","Azurill","Plusle","Minun","Banette","Pachirisu","Victini","Oshawott","Lillipup","Swoobat","Tympole","Sewaddle","Whimsicott","Sigilyph","Ducklett","Karrablast","Litwick","Meloetta Pirouette Forme-pirouette","Meloetta Pirouette Forme"],"legendgroup":"(8.325, 12.267]","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":
png","135_back.png","136_back.png","137_back.png","138_back.png","139_back.png","13_back.png","140_back.png","141_back.png","142_back.png","143_back.png","144_back.png","145_back.png","146_back.png","147_back.png","148_back.png","149_back.png","14_back.png","150_back.png","151_back.png","152_back.png","153_back.png","154_back.png","155_back.png","156_back.png","157_back.png","158_back.png","159_back.png","15_back.png","160_back.png","161_back.png","162_back.png","163_back.png","164_back.png","165_back.png","166_back.png","167_back.png","168_back.png","169_back.png","16_back.png","170_back.png","171_back.png","172_back.png","173_back.png","174_back.png","175_back.png","176_back.png","177_back.png","178_back.png","179_back.png","17_back.png","180_back.png","181_back.png","182_back.png","183_back.png","184_back.png","185_back.png","186_back.png","187_back.png","188_back.png","189_back.png","18_back.png","190_back.png","191_back.png","192_back.png","193_back.png","194_back.png","195_back.png","196_back.png","197_back.png","198_back.png","199_back.png","19_back.png","1_back.png","200_back.png","201_back.png","202_back.png","203_back.png","204_back.png","205_back.png","206_back.png","207_back.png","208_back.png","209_back.png","20_back.png","210_back.png","211_back.png","212_back.png","213_back.png","214_back.png","215_back.png","216_back.png","217_back.png","218_back.png","219_back.png","21_back.png","220_back.png","221_back.png","222_back.png","223_back.png","224_back.png","225_back.png","226_back.png","227_back.png","228_back.png","229_back.png","22_back.png","230_back.png","231_back.png","232_back.png","233_back.png","234_back.png","235_back.png","236_back.png","237_back.png","238_back.png","239_back.png","23_back.png","240_back.png","241_back.png","242_back.png","243_back.png","244_back.png","245_back.png","246_back.png","247_back.png","248_back.png","249_back.png","24_back.png","250_back.png","251_back.png","252_back.png","253_back.png","254_back.png","255_back.png","256_back.png","257_back.png","258_back.png","259_back.png","25_back.png","260_back.png","261_back.png","262_back.png","263_back.png","264_back.png","265_back.png","266_back.png","267_back.png","268_back.png","269_back.png","26_back.png","270_back.png","271_back.png","272_back.png","273_back.png","274_back.png","275_back.png","276_back.png","277_back.png","278_back.png","279_back.png","27_back.png","280_back.png","281_back.png","282_back.png","283_back.png","284_back.png","285_back.png","286_back.png","287_back.png","288_back.png","289_back.png","28_back.png","290_back.png","291_back.png","292_back.png","293_back.png","294_back.png","295_back.png","296_back.png","297_back.png","298_back.png","299_back.png","29_back.png","2_back.png","300_back.png","301_back.png","302_back.png"," ...

# %% [markdown]
# # 3D t-SNE

# %%
tsne = TSNE(n_components=3, init='pca', learning_rate='auto', verbose=1).fit_transform(embeddings)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3648 samples in 0.168s...
# [t-SNE] Computed neighbors for 3648 samples in 8.715s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3648
# [t-SNE] Computed conditional probabilities for sample 2000 / 3648
# [t-SNE] Computed conditional probabilities for sample 3000 / 3648
# [t-SNE] Computed conditional probabilities for sample 3648 / 3648
# [t-SNE] Mean sigma: 15.275189
# e:\dev\fusion-dance\env\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning:
#
# The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.489899
# [t-SNE] KL divergence after 1000 iterations: 1.014009

# %%
fig = px.scatter_3d(tsne, x=0, y=1, z=2, color=colors, labels={'color': label}, hover_name=filenames, title='3D t-SNE')
fig.show()
# Out:
# <div>                            <div id="c7d762e1-fd54-4756-a80e-fcf2279c9dbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7d762e1-fd54-4756-a80e-fcf2279c9dbf")) {                    Plotly.newPlot(                        "c7d762e1-fd54-4756-a80e-fcf2279c9dbf",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>type=back<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","hovertext":["back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","b ...
