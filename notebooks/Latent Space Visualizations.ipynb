# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA
import torch
import numpy as np
import pandas as pd
import plotly.express as px

# %%
# Config
embedding_location = "../outputs/vq_vae_v5.8/encodings.pt"
# embedding_location = "../outputs/ablation_vq_vae_v2.2/encodings.pt"
# embedding_location = "../outputs/base_convolutional_vae_v1/embeddings.pt"
# embedding_location = "../outputs/sprites_vq_vae_v2/encodings.pt"
# embedding_location = "../outputs/old_sprites_ablation_vq_vae_v2.2/encodings.pt"
# embedding_location = "../outputs/base_sprites_convolutional_vae_v1/embeddings.pt"
mode = "pokemon" # pokemon, sprites, tinyhero
# For Pokemon: height, weight, type1, type2, egg1, egg2, bmi;
# For sprites: id, pose, animation
label = "type1"

# %%
checkpoint = torch.load(embedding_location)
embeddings = checkpoint['embeddings']
filenames = checkpoint['filenames']
meta_information = checkpoint['color']

# %%
# Config
num_embeddings = embeddings.shape[0]
embeddings = embeddings.reshape(num_embeddings, -1)
# embeddings = embeddings * 256 # Use with encodings; swap the number for num_classes

# %%
if mode == "pokemon":
    all_colors = pd.DataFrame(meta_information, columns=["height", "weight", "type1", "type2", "egg1", "egg2"])
    if label in ["height", "weight"]:
        colors = pd.qcut(all_colors[label], 10)
    elif label == "bmi":
        colors = pd.qcut(all_colors["weight"] / all_colors["height"], 10)
    else:
        colors = all_colors[label]
elif mode == "sprites":
    all_colors = pd.DataFrame(meta_information, columns=["id", "pose", "animation"])
    colors = all_colors[label]
else:
    colors = meta_information
    label = "pose"

# %%
embeddings.shape
# Out:
# torch.Size([740, 1024])

# %%
embeddings[0]
# Out:
# tensor([0.5938, 0.5938, 0.5938,  ..., 0.5938, 0.5938, 0.5938])

# %% [markdown]
# # 2D t-SNE

# %%
tsne = TSNE(n_components=2, init='pca', perplexity=10, learning_rate='auto', verbose=1).fit_transform(embeddings)
# Out:
# [t-SNE] Computing 31 nearest neighbors...
# [t-SNE] Indexed 740 samples in 0.002s...
# [t-SNE] Computed neighbors for 740 samples in 0.046s...
# [t-SNE] Computed conditional probabilities for sample 740 / 740
# [t-SNE] Mean sigma: 0.762981
# e:\dev\fusion-dance\env\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning:
#
# The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 122.393417
# [t-SNE] KL divergence after 1000 iterations: 2.932643

# %%
fig = px.scatter(tsne, x=0, y=1, color=colors, labels={'color': label}, hover_name=filenames, title='2D t-SNE')
fig.show()
# Out:
# <div>                            <div id="fefe9157-8814-47fc-80ed-73b71bef041a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("fefe9157-8814-47fc-80ed-73b71bef041a")) {                    Plotly.newPlot(                        "fefe9157-8814-47fc-80ed-73b71bef041a",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>type1=Grass<br>0=%{x}<br>1=%{y}<extra></extra>","hovertext":["Bulbasaur","Ivysaur","Venusaur","Oddish","Gloom","Vileplume","Bellsprout","Weepinbell","Victreebel","Exeggcute","Exeggutor","Tangela","Chikorita","Bayleef","Meganium","Bellossom","Hoppip","Skiploom","Jumpluff","Sunkern","Sunflora","Treecko","Grovyle","Sceptile","Seedot","Nuzleaf","Shiftry","Shroomish","Breloom","Roselia","Cacnea","Cacturne","Tropius","Turtwig","Grotle","Torterra","Budew","Roserade","Cherubi","Cherrim-beta","Cherrim-sunshine","Cherrim","Carnivine","Snover","Abomasnow","Tangrowth","Leafeon","Shaymin Sky Forme-sky","Shaymin Sky Forme","Snivy","Servine","Serperior","Pansage","Simisage","Cottonee","Whimsicott","Petilil","Lilligant","Maractus","Foongus","Amoonguss","Ferroseed","Ferrothorn","Virizion"],"legendgroup":"Grass","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"
png","0013_left_slash4.png","0013_left_slash5.png","0013_left_slash6.png","0013_left_slash7.png","0013_left_spellcard0.png","0013_left_spellcard1.png","0013_left_spellcard2.png","0013_left_spellcard3.png","0013_left_spellcard4.png","0013_left_spellcard5.png","0013_left_spellcard6.png","0013_left_spellcard7.png","0013_left_walk0.png","0013_left_walk1.png","0013_left_walk2.png","0013_left_walk3.png","0013_left_walk4.png","0013_left_walk5.png","0013_left_walk6.png","0013_left_walk7.png","0013_right_slash0.png","0013_right_slash1.png","0013_right_slash2.png","0013_right_slash3.png","0013_right_slash4.png","0013_right_slash5.png","0013_right_slash6.png","0013_right_slash7.png","0013_right_spellcard0.png","0013_right_spellcard1.png","0013_right_spellcard2.png","0013_right_spellcard3.png","0013_right_spellcard4.png","0013_right_spellcard5.png","0013_right_spellcard6.png","0013_right_spellcard7.png","0013_right_walk0.png","0013_right_walk1.png","0013_right_walk2.png","0013_right_walk3.png","0013_right_walk4.png","0013_right_walk5.png","0013_right_walk6.png","0013_right_walk7.png"],"legendgroup":"0013","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"0013","showlegend":true,"x":[1.7078107946402332,1.2835127263374615,0.49618523791045677,0.6718186170918052,0.7550594863430397,0.7769680332133021,0.7550594863430456,1.7078107946402366,1.663284068964768,1.5255382102159105,1.0990734764570542,1.5447200302033013,1.2206232765501261,1.1926697271186975,1.2206232765501261,1.6318375413121624,1.2448979290169562,1.4566446518810365,1.2458716691596947,0.7575609276870465,1.3887099435557484,1.415765913082176,1.188752041284909,0.7137141164866039,0.08578695580217237,0.13444527501421913,0.28119694376354953,0.15800964672508958,0.336962277603566,0.29565626177122406,0.336962277603566,0.08578695580217237,0.10113185982016852,0.08134350068231011,0.051382605548562235,0.2405527360026467,0.22560298396578965,0.22737642401104294,0.22560298396578965,0.20837828187509308,0.24722816909351594,0.42886743307539216,0.16178561690324197,0.3838265733544287,0.3935223547753133,0.6860011502304328,0.42658157241674294,0.3838088410730766,0.05343896601168734,0.1446880672441067,0.46102549389110825,0.5514849311230748,0.4262163998914776,0.4302580584466661,0.4262163998914776,0.05343896601168734,0.07195976542371703,0.08173598629850738,0.03345838365720161,0.16144612403370875,0.3024079754943293,0.1460735205471443,0.3024079754943293,0.16483884440167004,0.05634088342621524,0.24642891776231973,0.05336322027755943,0.14771137041385285,0.13908174139335383,0.20381197677207905,0.26292804610072146,0.08924020491707835],"xaxis":"x","y":[0.6981199040688546,0.3434320720267283,0.144372323548 ...

# %% [markdown]
# # 3D t-SNE

# %%
tsne = TSNE(n_components=3, init='pca', learning_rate='auto', verbose=1).fit_transform(embeddings)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 3648 samples in 0.168s...
# [t-SNE] Computed neighbors for 3648 samples in 8.715s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 3648
# [t-SNE] Computed conditional probabilities for sample 2000 / 3648
# [t-SNE] Computed conditional probabilities for sample 3000 / 3648
# [t-SNE] Computed conditional probabilities for sample 3648 / 3648
# [t-SNE] Mean sigma: 15.275189
# e:\dev\fusion-dance\env\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning:
#
# The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 67.489899
# [t-SNE] KL divergence after 1000 iterations: 1.014009

# %%
fig = px.scatter_3d(tsne, x=0, y=1, z=2, color=colors, labels={'color': label}, hover_name=filenames, title='3D t-SNE')
fig.show()
# Out:
# <div>                            <div id="c7d762e1-fd54-4756-a80e-fcf2279c9dbf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c7d762e1-fd54-4756-a80e-fcf2279c9dbf")) {                    Plotly.newPlot(                        "c7d762e1-fd54-4756-a80e-fcf2279c9dbf",                        [{"hovertemplate":"<b>%{hovertext}</b><br><br>type=back<br>0=%{x}<br>1=%{y}<br>2=%{z}<extra></extra>","hovertext":["back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","back","b ...
